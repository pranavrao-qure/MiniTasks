# %% [markdown]
# # Analysing Embedding from OpenAI library #

# %%
from itertools import product
import time

import os
import openai

import numpy as np
import pandas as pd

import torch
import torch.nn.functional as F

# %%
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

torch.set_printoptions(linewidth=200)

# %% [markdown]
# ## Setting up OpenAI key ##
# Using personal key for access to OpenAI models

# %%
openai.api_key = os.getenv('OPENAI_API_KEY')
print(os.getenv('OPENAI_API_KEY'))
# Out:
# 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

# %% [markdown]
# ## Sanity Tests ##
# Few sanity tests for API

# %%
chat_completion = openai.ChatCompletion.create(model='gpt-3.5-turbo', messages=[{'role':'user', 'content':'Hello World'}])

# %%
print(chat_completion)
# Out:
# {
#   "id": "chatcmpl-7wNuAnEiHhF3vwy2GHU1CDChslGAJ",
#   "object": "chat.completion",
#   "created": 1694149270,
#   "model": "gpt-3.5-turbo-0613",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "Hello! How can I assist you today?"
#       },
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 9,
#     "completion_tokens": 9,
#     "total_tokens": 18
#   }
# }

# %% [markdown]
# ## Embeddings for reports ##
# Getting the embeddings and storing it in local files

# %%
def get_embedding(text, model="text-embedding-ada-002"):
   text = text.replace("\n", " ")
   return openai.Embedding.create(input = [text], model=model)['data'][0]['embedding']

# %%
sentence_list = ["The report shows small right-sided pleural effusion", "The report shows small left-sided pleural effusion",\
    "The report shows large right-sided pleural effusion", "The report shows large left-sided pleural effusion",\
    "There are no abnormalities in the report",\
    "There is severe consolidation in the left side","There is severe consolidation in the right side",\
    "There is mild consolidation in the right side", "There is mild consolidation in the left side"
]

# %%
sentence1_base = "A <SizeModifier> <AbnormalReport> can be seen in the report in the <LocationModifier> part"
sentence2_base = "The report shows a <SizeModifier> <LocationModifier> <AbnormalReport>"
size_modifiers = ['small', 'large']
loc_modifiers = ['upper-left', 'lower-left', 'right-sided', 'left-sided']
abnormal_report = ['pleural effusion']

l1 = [sentence1_base.replace('<SizeModifier>', size_mod).replace('<LocationModifier>', loc_mod).replace('<AbnormalReport>', ab_rep) for size_mod, loc_mod, ab_rep in product(size_modifiers, loc_modifiers, abnormal_report)]
l2 = [sentence2_base.replace('<SizeModifier>', size_mod).replace('<LocationModifier>', loc_mod).replace('<AbnormalReport>', ab_rep) for size_mod, loc_mod, ab_rep in product(size_modifiers, loc_modifiers, abnormal_report)]

# %%
negative_sentences = ['The report shows no pleural effusion', 'The report shows no consolidation on any side']
all_sentence_list = l1 + l2 + negative_sentences + sentence_list[4:]

# %%
print('\n'.join(all_sentence_list))
# Out:
# A small pleural effusion can be seen in the report in the upper-left part
# A small pleural effusion can be seen in the report in the lower-left part
# A small pleural effusion can be seen in the report in the right-sided part
# A small pleural effusion can be seen in the report in the left-sided part
# A large pleural effusion can be seen in the report in the upper-left part
# A large pleural effusion can be seen in the report in the lower-left part
# A large pleural effusion can be seen in the report in the right-sided part
# A large pleural effusion can be seen in the report in the left-sided part
# The report shows a small upper-left pleural effusion
# The report shows a small lower-left pleural effusion
# The report shows a small right-sided pleural effusion
# The report shows a small left-sided pleural effusion
# The report shows a large upper-left pleural effusion
# The report shows a large lower-left pleural effusion
# The report shows a large right-sided pleural effusion
# The report shows a large left-sided pleural effusion
# The report shows no pleural effusion
# The report shows no consolidation on any side
# There are no abnormalities in the report
# There is severe consolidation in the left side
# There is severe consolidation in the right side
# There is mild consolidation in the right side
# There is mild consolidation in the left side

# %%
df = pd.DataFrame({'report':all_sentence_list})
df['ada_embedding'] = df.report.apply(lambda x: get_embedding(x, model='text-embedding-ada-002'))
df.to_csv('embedded_test_sentences1.csv', index=False)

# %%
dataset1_template = """xr- chest pa  view
findings
lungs: normal.
trachea: normal.
carina: normal.
right and left main bronchi: normal.
pleura: normal.
heart: normal.
right heart border: normal.
left heart border: normal.
pulmonary bay: normal.
pulmonary hila: normal.
aorta: normal.
thoracic spine: normal.
other visualized bones: normal.
visualized soft tissues: normal.
diaphragm: normal.
visualized abdomen:  normal.
visualized neck: normal."""

dataset1_pleural_issue="""
xr- chest pa view
findings
lungs: normal.
trachea: normal.
carina: normal.
right and left main bronchi: normal.
pleura: left costophrenic angle is blunted with thin stripe of homogenous opacity along left lateral chest wall.
heart: normal.
right heart border: normal.
left heart border: normal.
pulmonary bay: normal.
pulmonary hila: normal.
aorta: normal.
thoracic spine: normal.
other visualized bones: normal.
visualized soft tissues: normal.
diaphragm: normal.
visualized abdomen:  normal.
visualized neck: normal."""

dataset2_template="""6191206|3862169|x-ray chest pa/ap view of 09-feb-2018:
results:
post cabg status.
no focal lesion seen in the lung parenchyma.
cp angles and domes of the diaphragm are normal.
both hila are normal. pulmonary vasculature is normal.
cardiac size and configuration is normal.
trachea is central; no mediastinal shift is seen.
bony thorax and soft tissues of the chest wall are normal.
impression: no abnormality detected in the view obtained.
"""

dataset3_template="""
x-ray chest (pa view)
the cardio thoracic ratio is normal.
the heart size and configuration are within normal limits.
the aortic arch is normal.
the lung fields show normal broncho-vascular markings.
both the pulmonary hila are normal in size.
the costophrenic and cardiophrenic recesses and the domes of
diaphragm are normal.
the bones and soft tissues of the chest wall show no abnormality.
impression : normal study.
dr.shakthi kumar
radiologist
ss
________________________________________________________
"""

# %%
df2 = pd.DataFrame({'report': [dataset1_template, dataset1_pleural_issue, dataset2_template, dataset3_template]})
df2['ada_embedding'] = df2.report.apply(lambda x: get_embedding(x, model='text-embedding-ada-002'))
df2.to_csv('embedded_test_sentences2.csv', index=False)

# %% [markdown]
# ## Consine matrix for the embeddings ##

# %%
def calc_cosine_sim_matrix(sentence_embeddings):
    stacked_sentence_embeddings = torch.stack(sentence_embeddings)
    # Calculate the cosine similarity matrix
    cosine_sim_matrix = F.cosine_similarity(stacked_sentence_embeddings.unsqueeze(1), stacked_sentence_embeddings.unsqueeze(0), dim=2)
    return stacked_sentence_embeddings, cosine_sim_matrix

# %%
def toList(list_str):
    return list(map(float, list_str[1:-1].split(', ')))

# %%
df1 = pd.read_csv('embedded_test_sentences1.csv')
df1.ada_embedding = df1.ada_embedding.apply(toList)

# %%
print(df1.head())
print(df1.describe())
# Out:
#                                               report                                      ada_embedding
# 0  A small pleural effusion can be seen in the re...  [-0.010283100418746471, 0.026601657271385193, ...
# 1  A small pleural effusion can be seen in the re...  [-0.01526658982038498, 0.026450255885720253, 0...
# 2  A small pleural effusion can be seen in the re...  [-0.018871692940592766, 0.026934247463941574, ...
# 3  A small pleural effusion can be seen in the re...  [-0.014083346351981163, 0.03057301975786686, 0...
# 4  A large pleural effusion can be seen in the re...  [-0.009492901153862476, 0.022884558886289597, ...
#                                                    report                                      ada_embedding
# count                                                  23                                                 23
# unique                                                 23                                                 23
# top     A small pleural effusion can be seen in the re...  [-0.010283100418746471, 0.026601657271385193, ...
# freq                                                    1                                                  1

# %%
_, consine_sim_matrix1 = calc_cosine_sim_matrix(list(torch.Tensor(df1.ada_embedding)))

# %%
print(consine_sim_matrix1)
# Out:
# tensor([[1.0000, 0.9907, 0.9726, 0.9775, 0.9891, 0.9837, 0.9609, 0.9670, 0.9690, 0.9528, 0.9464, 0.9519, 0.9624, 0.9520, 0.9372, 0.9443, 0.8964, 0.7881, 0.8011, 0.8569, 0.8461, 0.8709, 0.8781],
#         [0.9907, 1.0000, 0.9738, 0.9817, 0.9775, 0.9903, 0.9584, 0.9679, 0.9643, 0.9645, 0.9500, 0.9584, 0.9495, 0.9625, 0.9332, 0.9443, 0.8953, 0.7906, 0.7997, 0.8613, 0.8471, 0.8748, 0.8851],
#         [0.9726, 0.9738, 1.0000, 0.9861, 0.9617, 0.9659, 0.9881, 0.9745, 0.9488, 0.9421, 0.9655, 0.9556, 0.9384, 0.9382, 0.9571, 0.9460, 0.8960, 0.7991, 0.8047, 0.8683, 0.8771, 0.8979, 0.8870],
#         [0.9775, 0.9817, 0.9861, 1.0000, 0.9680, 0.9748, 0.9754, 0.9896, 0.9544, 0.9510, 0.9557, 0.9681, 0.9469, 0.9521, 0.9472, 0.9614, 0.8953, 0.7985, 0.8005, 0.8822, 0.8660, 0.8900, 0.9026],
#         [0.9891, 0.9775, 0.9617, 0.9680, 1.0000, 0.9902, 0.9718, 0.9778, 0.9509, 0.9337, 0.9284, 0.9359, 0.9737, 0.9558, 0.9493, 0.9551, 0.8912, 0.7897, 0.7975, 0.8640, 0.8541, 0.8602, 0.8678],
#         [0.9837, 0.9903, 0.9659, 0.9748, 0.9902, 1.0000, 0.9709, 0.9803, 0.9497, 0.9490, 0.9348, 0.9452, 0.9629, 0.9694, 0.9465, 0.9565, 0.8921, 0.7930, 0.7964, 0.8694, 0.8557, 0.8663, 0.8771],
#         [0.9609, 0.9584, 0.9881, 0.9754, 0.9718, 0.9709, 1.0000, 0.9855, 0.9291, 0.9207, 0.9461, 0.9380, 0.9505, 0.9409, 0.9705, 0.9573, 0.8906, 0.7986, 0.8001, 0.8755, 0.8858, 0.8866, 0.8758],
#         [0.9670, 0.9679, 0.9745, 0.9896, 0.9778, 0.9803, 0.9855, 1.0000, 0.9350, 0.9304, 0.9356, 0.9503, 0.9570, 0.9539, 0.9573, 0.9706, 0.8888, 0.7989, 0.7963, 0.8889, 0.8727, 0.8781, 0.8916],
#         [0.9690, 0.9643, 0.9488, 0.9544, 0.9509, 0.9497, 0.9291, 0.9350, 1.0000, 0.9871, 0.9786, 0.9824, 0.9706, 0.9681, 0.9467, 0.9546, 0.9259, 0.8051, 0.8234, 0.8506, 0.8417, 0.8811, 0.8859],
#         [0.9528, 0.9645, 0.9421, 0.9510, 0.9337, 0.9490, 0.9207, 0.9304, 0.9871, 1.0000, 0.9755, 0.9833, 0.9514, 0.9757, 0.9377, 0.9501, 0.9288, 0.8110, 0.8277, 0.8520, 0.8396, 0.8810, 0.8889],
#         [0.9464, 0.9500, 0.9655, 0.9557, 0.9284, 0.9348, 0.9461, 0.9356, 0.9786, 0.9755, 1.0000, 0.9882, 0.9469, 0.9546, 0.9690, 0.9590, 0.9210, 0.8152, 0.8253, 0.8608, 0.8707, 0.9040, 0.8922],
#         [0.9519, 0.9584, 0.9556, 0.9681, 0.9359, 0.9452, 0.9380, 0.9503, 0.9824, 0.9833, 0.9882, 1.0000, 0.9554, 0.9682, 0.9597, 0.9751, 0.9217, 0.8182, 0.8230, 0.8737, 0.8598, 0.8959, 0.9061],
#         [0.9624, 0.9495, 0.9384, 0.9469, 0.9737, 0.9629, 0.9505, 0.9570, 0.9706, 0.9514, 0.9469, 0.9554, 1.0000, 0.9789, 0.9737, 0.9802, 0.9118, 0.7988, 0.8091, 0.8662, 0.8576, 0.8607, 0.8676],
#         [0.9520, 0.9625, 0.9382, 0.9521, 0.9558, 0.9694, 0.9409, 0.9539, 0.9681, 0.9757, 0.9546, 0.9682, 0.9789, 1.0000, 0.9637, 0.9779, 0.9138, 0.8038, 0.8088, 0.8712, 0.8566, 0.8667, 0.8790],
#         [0.9372, 0.9332, 0.9571, 0.9472, 0.9493, 0.9465, 0.9705, 0.9573, 0.9467, 0.9377, 0.9690, 0.9597, 0.9737, 0.9637, 1.0000, 0.9847, 0.9074, 0.8116, 0.8116, 0.8772, 0.8905, 0.8855, 0.8732],
#         [0.9443, 0.9443, 0.9460, 0.9614, 0.9551, 0.9565, 0.9573, 0.9706, 0.9546, 0.9501, 0.9590, 0.9751, 0.9802, 0.9779, 0.9847, 1.0000, 0.9083, 0.8157, 0.8096, 0.8914, 0.8772, 0.8789, 0.8914],
#         [0.8964, 0.8953, 0.8960, 0.8953, 0.8912, 0.8921, 0.8906, 0.8888, 0.9259, 0.9288, 0.9210, 0.9217, 0.9118, 0.9138, 0.9074, 0.9083, 1.0000, 0.8496, 0.8837, 0.8128, 0.8083, 0.8405, 0.8409],
#         [0.7881, 0.7906, 0.7991, 0.7985, 0.7897, 0.7930, 0.7986, 0.7989, 0.8051, 0.8110, 0.8152, 0.8182, 0.7988, 0.8038, 0.8116, 0.8157, 0.8496, 1.0000, 0.8512, 0.8509, 0.8490, 0.8413, 0.8385],
#         [0.8011, 0.7997, 0.8047, 0.8005, 0.7975, 0.7964, 0.8001, 0.7963, 0.8234, 0.8277, 0.8253, 0.8230, 0.8091, 0.8088, 0.8116, 0.8096, 0.8837, 0.8512, 1.0000, 0.7747, 0.7781, 0.8034, 0.7968],
#         [0.8569, 0.8613, 0.8683, 0.8822, 0.8640, 0.8694, 0.8755, 0.8889, 0.8506, 0.8520, 0.8608, 0.8737, 0.8662, 0.8712, 0.8772, 0.8914, 0.8128, 0.8509, 0.7747, 1.0000, 0.9811, 0.9504, 0.9636],
#         [0.8461, 0.8471, 0.8771, 0.8660, 0.8541, 0.8557, 0.8858, 0.8727, 0.8417, 0.8396, 0.8707, 0.8598, 0.8576, 0.8566, 0.8905, 0.8772, 0.8083, 0.8490, 0.7781, 0.9811, 1.0000, 0.9608, 0.9430],
#         [0.8709, 0.8748, 0.8979, 0.8900, 0.8602, 0.8663, 0.8866, 0.8781, 0.8811, 0.8810, 0.9040, 0.8959, 0.8607, 0.8667, 0.8855, 0.8789, 0.8405, 0.8413, 0.8034, 0.9504, 0.9608, 1.0000, 0.9849],
#         [0.8781, 0.8851, 0.8870, 0.9026, 0.8678, 0.8771, 0.8758, 0.8916, 0.8859, 0.8889, 0.8922, 0.9061, 0.8676, 0.8790, 0.8732, 0.8914, 0.8409, 0.8385, 0.7968, 0.9636, 0.9430, 0.9849, 1.0000]])

# %%
df2 = pd.read_csv('embedded_test_sentences2.csv')
df2.ada_embedding = df2.ada_embedding.apply(toList)

# %%
print(df2.head())
print(df2.describe())
# Out:
#                                               report                                      ada_embedding
# 0  xr- chest pa  view\nfindings\nlungs: normal.\n...  [-0.018094871193170547, 0.01764216646552086, 0...
# 1  \nxr- chest pa view\nfindings\nlungs: normal.\...  [-0.021756017580628395, 0.028477167710661888, ...
# 2  6191206|3862169|x-ray chest pa/ap view of 09-f...  [-0.010397231206297874, 0.026680193841457367, ...
# 3  \nx-ray chest (pa view)\nthe cardio thoracic r...  [0.0025291878264397383, 0.019118065014481544, ...
#                                                    report                                      ada_embedding
# count                                                   4                                                  4
# unique                                                  4                                                  4
# top     xr- chest pa  view\nfindings\nlungs: normal.\n...  [-0.018094871193170547, 0.01764216646552086, 0...
# freq                                                    1                                                  1

# %%
_, consine_sim_matrix2 = calc_cosine_sim_matrix(list(torch.Tensor(df2.ada_embedding)))

# %%
print(consine_sim_matrix2)
# Out:
# tensor([[1.0000, 0.9637, 0.9024, 0.9125],
#         [0.9637, 1.0000, 0.8912, 0.9063],
#         [0.9024, 0.8912, 1.0000, 0.9116],
#         [0.9125, 0.9063, 0.9116, 1.0000]])

# %% [markdown]
# ## Misc Tests ##

# %%
print(df2.ada_embedding)
print(torch.Tensor(df2.ada_embedding))
print(torch.Tensor([[1, 2, 3], [1, 1, 5]]))
_, consine_sim_matrix3 = calc_cosine_sim_matrix(list(torch.Tensor([[1, 2, 3], [1, 1, 5]])))
print(consine_sim_matrix3)
# Out:
# 0    [-0.018094871193170547, 0.01764216646552086, 0...
# 1    [-0.021756017580628395, 0.028477167710661888, ...
# 2    [-0.010397231206297874, 0.026680193841457367, ...
# 3    [0.0025291878264397383, 0.019118065014481544, ...
# Name: ada_embedding, dtype: object
# tensor([[-0.0181,  0.0176,  0.0213,  ...,  0.0016, -0.0061, -0.0341],
#         [-0.0218,  0.0285,  0.0143,  ...,  0.0073,  0.0019, -0.0346],
#         [-0.0104,  0.0267,  0.0137,  ..., -0.0061, -0.0096, -0.0348],
#         [ 0.0025,  0.0191,  0.0113,  ..., -0.0061,  0.0004, -0.0397]])
# tensor([[1., 2., 3.],
#         [1., 1., 5.]])
# tensor([[1.0000, 0.9258],
#         [0.9258, 1.0000]])

# %% [markdown]
# ## GPT 4 ##
# Testing GPT 4 models for similarity ratings

# %%
openai.api_key = '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'
content = "You will be provided with pair of radiological reports, rate their similarity based on sex, age, features, abnormalities, their locations and severity out of 100"

def rate_qa_pair(question, answer):
    prompt_text = f'Rate the following pair for similarity:\n\nQuestion: {question}\nAnswer: {answer}\n\nRating out of 100:'
    response = openai.ChatCompletion.create(
      model="gpt-4",
      messages = [
          {
      "role": "system",
      "content": content,
    },
    {
      "role": "user",
      "content": prompt_text
      }
      ],
      temperature=0,
      max_tokens=1024
    )    
    rating = response.choices[0]['message']['content'].strip()
    return rating

# %%
question = "AP x-ray of a 50yr old male. pleural effusion in the left lobe"
answer = "PA x-ray of a 60yr old female. small amount of fluid found in the left sided pleura"

# %%
print(rate_qa_pair(question, answer))
# Out:
# 70

# %%
#df3 = pd.DataFrame({'report':all_sentence_list})
#df3['gpt4_embedding'] = df3.report.apply(lambda x: get_embedding(x, model='text-embedding-ada-002'))
#df.to_csv('embedded_test_sentences1.csv', index=False)

# %%
similarity_map2 = dict()

# %%
for i in range(len(all_sentence_list)):
    for j in range(i, len(all_sentence_list)):
        s1 = all_sentence_list[i]
        s2 = all_sentence_list[j]
        print(f'Rating the pairs:\n{s1}\n###################\n{s2}')
        similarity_map2[f'{i}_{j}'] = rate_qa_pair(s1, s2)
        time.sleep(10)
# Out:
# Rating the pairs:
# A small pleural effusion can be seen in the report in the upper-left part
# ###################
# A small pleural effusion can be seen in the report in the upper-left part
# Rating the pairs:
# A small pleural effusion can be seen in the report in the upper-left part
# ###################
# A small pleural effusion can be seen in the report in the lower-left part
# Rating the pairs:
# A small pleural effusion can be seen in the report in the upper-left part
# ###################
# A small pleural effusion can be seen in the report in the right-sided part
# Rating the pairs:
# A small pleural effusion can be seen in the report in the upper-left part
# ###################
# A small pleural effusion can be seen in the report in the left-sided part
# Rating the pairs:
# A small pleural effusion can be seen in the report in the upper-left part
# ###################
# A large pleural effusion can be seen in the report in the upper-left part
# Rating the pairs:
# A small pleural effusion can be seen in the report in the upper-left part
# ###################
# A large pleural effusion can be seen in the report in the lower-left part
# Rating the pairs:
# A small pleural effusion can be seen in the report in the upper-left part
# ###################
# A large pleural effusion can be seen in the report in the right-sided part
# Rating the pairs:
# A small pleural effusion can be seen in the report in the upper-left part
# ###################
# A large pleural effusion can be seen in the report in the left-sided part
# Rating the pairs:
# A small pleural effusion can be seen in the report in the upper-left part
# ###################
# The report shows a small upper-left pleural effusion
# Rating the pairs:
# A small pleural effusion can be seen in the report in the upper-left part
# ###################
# The report shows a small lower-left pleural effusion
# Rating the pairs:
# A small pleural effusion can be seen in the report in the upper-left part
# ###################
# The report shows a small right-sided pleural effusion
# Rating the pairs:
# A small pleural effusion can be seen in the report in the upper-left part
# ###################
# The report shows a small left-sided pleural effusion
# Rating the pairs:
# A small pleural effusion can be seen in the report in the upper-left part
# ###################
# The report shows a large upper-left pleural effusion
# Rating the pairs:
# A small pleural effusion can be seen in the report in the upper-left part
# ###################
# The report shows a large lower-left pleural effusion
# Rating the pairs:
# A small pleural effusion can be seen in the report in the upper-left part
# ###################
# The report shows a large right-sided pleural effusion
# Rating the pairs:
# A small pleural effusion can be seen in the report in the upper-left part
# ###################
# The report shows a large left-sided pleural effusion
# Rating the pairs:
# A small pleural effusion can be seen in the report in the upper-left part
# ###################
# The report shows no pleural effusion
# Rating the pairs:
# A small pleural effusion can be seen in the report in the upper-left part
# ###################
# The report shows no consolidation on any side
# Rating the pairs:
# A small pleural effusion can be seen in the report in the upper-left part
# ###################
# There are no abnormalities in the report
# Rating the pairs:
# A small pleural effusion can be seen in the report in the upper-left part
# ###################
# There is severe consolidation in the left side
# Rating the pairs:
# A small pleural effusion can be seen in the report in the upper-left part
# ###################
# There is severe consolidation in the right side
# Rating the pairs:
# A small pleural effusion can be seen in the report in the upper-left part
# ###################
# There is mild consolidation in the right side
# Rating the pairs:
# A small pleural effusion can be seen in the report in the upper-left part
# ###################
# There is mild consolidation in the left side
# Rating the pairs:
# A small pleural effusion can be seen in the report in the lower-left part
# ###################
# A small pleural effusion can be seen in the report in the lower-left part
# Rating the pairs:
# A small pleural effusion can be seen in the report in the lower-left part
# ###################
# A small pleural effusion can be seen in the report in the right-sided part
# Rating the pairs:
# A small pleural effusion can be seen in the report in the lower-left part
# ###################
# A small pleural effusion can be seen in the report in the left-sided part
# Rating the pairs:
# A small pleural effusion can be seen in the report in the lower-left part
# ###################
# A large pleural effusion can be seen in the report in the upper-left part
# Rating the pairs:
# A small pleural effusion can be seen in the report in the lower-left part
# ###################
# A large pleural effusion can be seen in the report in the lower-left part
# Rating the pairs:
# A small pleural effusion can be seen in the report in the lower-left part
# ###################
# A large pleural effusion can be seen in the report in the right-sided part
# Rating the pairs:
# A small pleural effusion can be seen in the report in the lower-left part
# ###################
# A large pleural effusion can be seen in the report in the left-sided part
# Rating the pairs:
# A small pleural effusion can be seen in the report in the lower-left part
# ###################
# The report shows a small upper-left pleural effusion
# Rating the pairs:
# A small pleural effusion can be seen in the report in the lower-left part
# ###################
# The report shows a small lower-left pleural effusion
# Rating the pairs:
# A small pleural effusion can be seen in the report in the lower-left part
# ###################
# The report shows a small right-sided pleural effusion
# Rating the pairs:
# A small pleural effusion can be seen in the report in the lower-left part
# ###################
# The report shows a small left-sided pleural effusion
# Rating the pairs:
# A small pleural effusion can be seen in the report in the lower-left part
# ###################
# The report shows a large upper-left pleural effusion
# Rating the pairs:
# A small pleural effusion can be seen in the report in the lower-left part
# ###################
# The report shows a large lower-left pleural effusion
# Rating the pairs:
# A small pleural effusion can be seen in the report in the lower-left part
# ###################
# The report shows a large right-sided pleural effusion
# Rating the pairs:
# A small pleural effusion can be seen in the report in the lower-left part
# ###################
# The report shows a large left-sided pleural effusion
# Rating the pairs:
# A small pleural effusion can be seen in the report in the lower-left part
# ###################
# The report shows no pleural effusion
# Rating the pairs:
# A small pleural effusion can be seen in the report in the lower-left part
# ###################
# The report shows no consolidation on any side
# Rating the pairs:
# A small pleural effusion can be seen in the report in the lower-left part
# ###################
# There are no abnormalities in the report
# Rating the pairs:
# A small pleural effusion can be seen in the report in the lower-left part
# ###################
# There is severe consolidation in the left side
# Rating the pairs:
# A small pleural effusion can be seen in the report in the lower-left part
# ###################
# There is severe consolidation in the right side
# Rating the pairs:
# A small pleural effusion can be seen in the report in the lower-left part
# ###################
# There is mild consolidation in the right side
# Rating the pairs:
# A small pleural effusion can be seen in the report in the lower-left part
# ###################
# There is mild consolidation in the left side
# Rating the pairs:
# A small pleural effusion can be seen in the report in the right-sided part
# ###################
# A small pleural effusion can be seen in the report in the right-sided part
# Rating the pairs:
# A small pleural effusion can be seen in the report in the right-sided part
# ###################
# A small pleural effusion can be seen in the report in the left-sided part
# Rating the pairs:
# A small pleural effusion can be seen in the report in the right-sided part
# ###################
# A large pleural effusion can be seen in the report in the upper-left part
# Rating the pairs:
# A small pleural effusion can be seen in the report in the right-sided part
# ###################
# A large pleural effusion can be seen in the report in the lower-left part
# Rating the pairs:
# A small pleural effusion can be seen in the report in the right-sided part
# ###################
# A large pleural effusion can be seen in the report in the right-sided part
# Rating the pairs:
# A small pleural effusion can be seen in the report in the right-sided part
# ###################
# A large pleural effusion can be seen in the report in the left-sided part
# Rating the pairs:
# A small pleural effusion can be seen in the report in the right-sided part
# ###################
# The report shows a small upper-left pleural effusion
# Rating the pairs:
# A small pleural effusion can be seen in the report in the right-sided part
# ###################
# The report shows a small lower-left pleural effusion
# Rating the pairs:
# A small pleural effusion can be seen in the report in the right-sided part
# ###################
# The report shows a small right-sided pleural effusion
# Rating the pairs:
# A small pleural effusion can be seen in the report in the right-sided part
# ###################
# The report shows a small left-sided pleural effusion
# Rating the pairs:
# A small pleural effusion can be seen in the report in the right-sided part
# ###################
# The report shows a large upper-left pleural effusion
# Rating the pairs:
# A small pleural effusion can be seen in the report in the right-sided part
# ###################
# The report shows a large lower-left pleural effusion
# Rating the pairs:
# A small pleural effusion can be seen in the report in the right-sided part
# ###################
# The report shows a large right-sided pleural effusion
# Rating the pairs:
# A small pleural effusion can be seen in the report in the right-sided part
# ###################
# The report shows a large left-sided pleural effusion
# Rating the pairs:
# A small pleural effusion can be seen in the report in the right-sided part
# ###################
# The report shows no pleural effusion
# Rating the pairs:
# A small pleural effusion can be seen in the report in the right-sided part
# ###################
# The report shows no consolidation on any side
# Rating the pairs:
# A small pleural effusion can be seen in the report in the right-sided part
# ###################
# There are no abnormalities in the report
# Rating the pairs:
# A small pleural effusion can be seen in the report in the right-sided part
# ###################
# There is severe consolidation in the left side
# Rating the pairs:
# A small pleural effusion can be seen in the report in the right-sided part
# ###################
# There is severe consolidation in the right side
# Rating the pairs:
# A small pleural effusion can be seen in the report in the right-sided part
# ###################
# There is mild consolidation in the right side
# Rating the pairs:
# A small pleural effusion can be seen in the report in the right-sided part
# ###################
# There is mild consolidation in the left side
# Rating the pairs:
# A small pleural effusion can be seen in the report in the left-sided part
# ###################
# A small pleural effusion can be seen in the report in the left-sided part
# Rating the pairs:
# A small pleural effusion can be seen in the report in the left-sided part
# ###################
# A large pleural effusion can be seen in the report in the upper-left part
# Rating the pairs:
# A small pleural effusion can be seen in the report in the left-sided part
# ###################
# A large pleural effusion can be seen in the report in the lower-left part
# Rating the pairs:
# A small pleural effusion can be seen in the report in the left-sided part
# ###################
# A large pleural effusion can be seen in the report in the right-sided part
# Rating the pairs:
# A small pleural effusion can be seen in the report in the left-sided part
# ###################
# A large pleural effusion can be seen in the report in the left-sided part
# Rating the pairs:
# A small pleural effusion can be seen in the report in the left-sided part
# ###################
# The report shows a small upper-left pleural effusion
# Rating the pairs:
# A small pleural effusion can be seen in the report in the left-sided part
# ###################
# The report shows a small lower-left pleural effusion
# Rating the pairs:
# A small pleural effusion can be seen in the report in the left-sided part
# ###################
# The report shows a small right-sided pleural effusion
# Rating the pairs:
# A small pleural effusion can be seen in the report in the left-sided part
# ###################
# The report shows a small left-sided pleural effusion
# Rating the pairs:
# A small pleural effusion can be seen in the report in the left-sided part
# ###################
# The report shows a large upper-left pleural effusion
# Rating the pairs:
# A small pleural effusion can be seen in the report in the left-sided part
# ###################
# The report shows a large lower-left pleural effusion
# Rating the pairs:
# A small pleural effusion can be seen in the report in the left-sided part
# ###################
# The report shows a large right-sided pleural effusion
# Rating the pairs:
# A small pleural effusion can be seen in the report in the left-sided part
# ###################
# The report shows a large left-sided pleural effusion
# Rating the pairs:
# A small pleural effusion can be seen in the report in the left-sided part
# ###################
# The report shows no pleural effusion
# Rating the pairs:
# A small pleural effusion can be seen in the report in the left-sided part
# ###################
# The report shows no consolidation on any side
# Rating the pairs:
# A small pleural effusion can be seen in the report in the left-sided part
# ###################
# There are no abnormalities in the report
# Rating the pairs:
# A small pleural effusion can be seen in the report in the left-sided part
# ###################
# There is severe consolidation in the left side
# Rating the pairs:
# A small pleural effusion can be seen in the report in the left-sided part
# ###################
# There is severe consolidation in the right side
# Rating the pairs:
# A small pleural effusion can be seen in the report in the left-sided part
# ###################
# There is mild consolidation in the right side
# Rating the pairs:
# A small pleural effusion can be seen in the report in the left-sided part
# ###################
# There is mild consolidation in the left side
# Rating the pairs:
# A large pleural effusion can be seen in the report in the upper-left part
# ###################
# A large pleural effusion can be seen in the report in the upper-left part
# Rating the pairs:
# A large pleural effusion can be seen in the report in the upper-left part
# ###################
# A large pleural effusion can be seen in the report in the lower-left part
# Rating the pairs:
# A large pleural effusion can be seen in the report in the upper-left part
# ###################
# A large pleural effusion can be seen in the report in the right-sided part
# Rating the pairs:
# A large pleural effusion can be seen in the report in the upper-left part
# ###################
# A large pleural effusion can be seen in the report in the left-sided part
# Rating the pairs:
# A large pleural effusion can be seen in the report in the upper-left part
# ###################
# The report shows a small upper-left pleural effusion
# Rating the pairs:
# A large pleural effusion can be seen in the report in the upper-left part
# ###################
# The report shows a small lower-left pleural effusion
# Rating the pairs:
# A large pleural effusion can be seen in the report in the upper-left part
# ###################
# The report shows a small right-sided pleural effusion
# Rating the pairs:
# A large pleural effusion can be seen in the report in the upper-left part
# ###################
# The report shows a small left-sided pleural effusion
# Rating the pairs:
# A large pleural effusion can be seen in the report in the upper-left part
# ###################
# The report shows a large upper-left pleural effusion
# Rating the pairs:
# A large pleural effusion can be seen in the report in the upper-left part
# ###################
# The report shows a large lower-left pleural effusion
# Rating the pairs:
# A large pleural effusion can be seen in the report in the upper-left part
# ###################
# The report shows a large right-sided pleural effusion
# Rating the pairs:
# A large pleural effusion can be seen in the report in the upper-left part
# ###################
# The report shows a large left-sided pleural effusion
# Rating the pairs:
# A large pleural effusion can be seen in the report in the upper-left part
# ###################
# The report shows no pleural effusion
# Rating the pairs:
# A large pleural effusion can be seen in the report in the upper-left part
# ###################
# The report shows no consolidation on any side
# Rating the pairs:
# A large pleural effusion can be seen in the report in the upper-left part
# ###################
# There are no abnormalities in the report
# Rating the pairs:
# A large pleural effusion can be seen in the report in the upper-left part
# ###################
# There is severe consolidation in the left side
# Rating the pairs:
# A large pleural effusion can be seen in the report in the upper-left part
# ###################
# There is severe consolidation in the right side
# Rating the pairs:
# A large pleural effusion can be seen in the report in the upper-left part
# ###################
# There is mild consolidation in the right side
# Rating the pairs:
# A large pleural effusion can be seen in the report in the upper-left part
# ###################
# There is mild consolidation in the left side
# Rating the pairs:
# A large pleural effusion can be seen in the report in the lower-left part
# ###################
# A large pleural effusion can be seen in the report in the lower-left part
# Rating the pairs:
# A large pleural effusion can be seen in the report in the lower-left part
# ###################
# A large pleural effusion can be seen in the report in the right-sided part
# Rating the pairs:
# A large pleural effusion can be seen in the report in the lower-left part
# ###################
# A large pleural effusion can be seen in the report in the left-sided part
# Rating the pairs:
# A large pleural effusion can be seen in the report in the lower-left part
# ###################
# The report shows a small upper-left pleural effusion
# Rating the pairs:
# A large pleural effusion can be seen in the report in the lower-left part
# ###################
# The report shows a small lower-left pleural effusion
# Rating the pairs:
# A large pleural effusion can be seen in the report in the lower-left part
# ###################
# The report shows a small right-sided pleural effusion
# Rating the pairs:
# A large pleural effusion can be seen in the report in the lower-left part
# ###################
# The report shows a small left-sided pleural effusion
# Rating the pairs:
# A large pleural effusion can be seen in the report in the lower-left part
# ###################
# The report shows a large upper-left pleural effusion
# Rating the pairs:
# A large pleural effusion can be seen in the report in the lower-left part
# ###################
# The report shows a large lower-left pleural effusion
# Rating the pairs:
# A large pleural effusion can be seen in the report in the lower-left part
# ###################
# The report shows a large right-sided pleural effusion
# Rating the pairs:
# A large pleural effusion can be seen in the report in the lower-left part
# ###################
# The report shows a large left-sided pleural effusion
# Rating the pairs:
# A large pleural effusion can be seen in the report in the lower-left part
# ###################
# The report shows no pleural effusion
# Rating the pairs:
# A large pleural effusion can be seen in the report in the lower-left part
# ###################
# The report shows no consolidation on any side
# Rating the pairs:
# A large pleural effusion can be seen in the report in the lower-left part
# ###################
# There are no abnormalities in the report
# Rating the pairs:
# A large pleural effusion can be seen in the report in the lower-left part
# ###################
# There is severe consolidation in the left side
# Rating the pairs:
# A large pleural effusion can be seen in the report in the lower-left part
# ###################
# There is severe consolidation in the right side
# Rating the pairs:
# A large pleural effusion can be seen in the report in the lower-left part
# ###################
# There is mild consolidation in the right side
# Rating the pairs:
# A large pleural effusion can be seen in the report in the lower-left part
# ###################
# There is mild consolidation in the left side
# Rating the pairs:
# A large pleural effusion can be seen in the report in the right-sided part
# ###################
# A large pleural effusion can be seen in the report in the right-sided part
# Rating the pairs:
# A large pleural effusion can be seen in the report in the right-sided part
# ###################
# A large pleural effusion can be seen in the report in the left-sided part
# Rating the pairs:
# A large pleural effusion can be seen in the report in the right-sided part
# ###################
# The report shows a small upper-left pleural effusion
# Rating the pairs:
# A large pleural effusion can be seen in the report in the right-sided part
# ###################
# The report shows a small lower-left pleural effusion
# Rating the pairs:
# A large pleural effusion can be seen in the report in the right-sided part
# ###################
# The report shows a small right-sided pleural effusion
# Rating the pairs:
# A large pleural effusion can be seen in the report in the right-sided part
# ###################
# The report shows a small left-sided pleural effusion
# Rating the pairs:
# A large pleural effusion can be seen in the report in the right-sided part
# ###################
# The report shows a large upper-left pleural effusion
# Rating the pairs:
# A large pleural effusion can be seen in the report in the right-sided part
# ###################
# The report shows a large lower-left pleural effusion
# Rating the pairs:
# A large pleural effusion can be seen in the report in the right-sided part
# ###################
# The report shows a large right-sided pleural effusion
# Rating the pairs:
# A large pleural effusion can be seen in the report in the right-sided part
# ###################
# The report shows a large left-sided pleural effusion
# Rating the pairs:
# A large pleural effusion can be seen in the report in the right-sided part
# ###################
# The report shows no pleural effusion
# Rating the pairs:
# A large pleural effusion can be seen in the report in the right-sided part
# ###################
# The report shows no consolidation on any side
# Rating the pairs:
# A large pleural effusion can be seen in the report in the right-sided part
# ###################
# There are no abnormalities in the report
# Rating the pairs:
# A large pleural effusion can be seen in the report in the right-sided part
# ###################
# There is severe consolidation in the left side
# Rating the pairs:
# A large pleural effusion can be seen in the report in the right-sided part
# ###################
# There is severe consolidation in the right side
# Rating the pairs:
# A large pleural effusion can be seen in the report in the right-sided part
# ###################
# There is mild consolidation in the right side
# Rating the pairs:
# A large pleural effusion can be seen in the report in the right-sided part
# ###################
# There is mild consolidation in the left side
# Rating the pairs:
# A large pleural effusion can be seen in the report in the left-sided part
# ###################
# A large pleural effusion can be seen in the report in the left-sided part
# Rating the pairs:
# A large pleural effusion can be seen in the report in the left-sided part
# ###################
# The report shows a small upper-left pleural effusion
# Rating the pairs:
# A large pleural effusion can be seen in the report in the left-sided part
# ###################
# The report shows a small lower-left pleural effusion
# Rating the pairs:
# A large pleural effusion can be seen in the report in the left-sided part
# ###################
# The report shows a small right-sided pleural effusion
# Rating the pairs:
# A large pleural effusion can be seen in the report in the left-sided part
# ###################
# The report shows a small left-sided pleural effusion
# Rating the pairs:
# A large pleural effusion can be seen in the report in the left-sided part
# ###################
# The report shows a large upper-left pleural effusion
# Rating the pairs:
# A large pleural effusion can be seen in the report in the left-sided part
# ###################
# The report shows a large lower-left pleural effusion
# Rating the pairs:
# A large pleural effusion can be seen in the report in the left-sided part
# ###################
# The report shows a large right-sided pleural effusion
# Rating the pairs:
# A large pleural effusion can be seen in the report in the left-sided part
# ###################
# The report shows a large left-sided pleural effusion
# Rating the pairs:
# A large pleural effusion can be seen in the report in the left-sided part
# ###################
# The report shows no pleural effusion
# Rating the pairs:
# A large pleural effusion can be seen in the report in the left-sided part
# ###################
# The report shows no consolidation on any side
# Rating the pairs:
# A large pleural effusion can be seen in the report in the left-sided part
# ###################
# There are no abnormalities in the report
# Rating the pairs:
# A large pleural effusion can be seen in the report in the left-sided part
# ###################
# There is severe consolidation in the left side
# Rating the pairs:
# A large pleural effusion can be seen in the report in the left-sided part
# ###################
# There is severe consolidation in the right side
# Rating the pairs:
# A large pleural effusion can be seen in the report in the left-sided part
# ###################
# There is mild consolidation in the right side
# Rating the pairs:
# A large pleural effusion can be seen in the report in the left-sided part
# ###################
# There is mild consolidation in the left side
# Rating the pairs:
# The report shows a small upper-left pleural effusion
# ###################
# The report shows a small upper-left pleural effusion
# Rating the pairs:
# The report shows a small upper-left pleural effusion
# ###################
# The report shows a small lower-left pleural effusion
# Rating the pairs:
# The report shows a small upper-left pleural effusion
# ###################
# The report shows a small right-sided pleural effusion
# Rating the pairs:
# The report shows a small upper-left pleural effusion
# ###################
# The report shows a small left-sided pleural effusion
# Rating the pairs:
# The report shows a small upper-left pleural effusion
# ###################
# The report shows a large upper-left pleural effusion
# Rating the pairs:
# The report shows a small upper-left pleural effusion
# ###################
# The report shows a large lower-left pleural effusion
# Rating the pairs:
# The report shows a small upper-left pleural effusion
# ###################
# The report shows a large right-sided pleural effusion
# Rating the pairs:
# The report shows a small upper-left pleural effusion
# ###################
# The report shows a large left-sided pleural effusion
# Rating the pairs:
# The report shows a small upper-left pleural effusion
# ###################
# The report shows no pleural effusion
# Rating the pairs:
# The report shows a small upper-left pleural effusion
# ###################
# The report shows no consolidation on any side
# Rating the pairs:
# The report shows a small upper-left pleural effusion
# ###################
# There are no abnormalities in the report
# Rating the pairs:
# The report shows a small upper-left pleural effusion
# ###################
# There is severe consolidation in the left side
# Rating the pairs:
# The report shows a small upper-left pleural effusion
# ###################
# There is severe consolidation in the right side
# Rating the pairs:
# The report shows a small upper-left pleural effusion
# ###################
# There is mild consolidation in the right side
# Rating the pairs:
# The report shows a small upper-left pleural effusion
# ###################
# There is mild consolidation in the left side
# Rating the pairs:
# The report shows a small lower-left pleural effusion
# ###################
# The report shows a small lower-left pleural effusion
# Rating the pairs:
# The report shows a small lower-left pleural effusion
# ###################
# The report shows a small right-sided pleural effusion
# Rating the pairs:
# The report shows a small lower-left pleural effusion
# ###################
# The report shows a small left-sided pleural effusion
# Rating the pairs:
# The report shows a small lower-left pleural effusion
# ###################
# The report shows a large upper-left pleural effusion
# Rating the pairs:
# The report shows a small lower-left pleural effusion
# ###################
# The report shows a large lower-left pleural effusion
# Rating the pairs:
# The report shows a small lower-left pleural effusion
# ###################
# The report shows a large right-sided pleural effusion
# Rating the pairs:
# The report shows a small lower-left pleural effusion
# ###################
# The report shows a large left-sided pleural effusion
# Rating the pairs:
# The report shows a small lower-left pleural effusion
# ###################
# The report shows no pleural effusion
# Rating the pairs:
# The report shows a small lower-left pleural effusion
# ###################
# The report shows no consolidation on any side
# Rating the pairs:
# The report shows a small lower-left pleural effusion
# ###################
# There are no abnormalities in the report
# Rating the pairs:
# The report shows a small lower-left pleural effusion
# ###################
# There is severe consolidation in the left side
# Rating the pairs:
# The report shows a small lower-left pleural effusion
# ###################
# There is severe consolidation in the right side
# Rating the pairs:
# The report shows a small lower-left pleural effusion
# ###################
# There is mild consolidation in the right side
# Rating the pairs:
# The report shows a small lower-left pleural effusion
# ###################
# There is mild consolidation in the left side
# Rating the pairs:
# The report shows a small right-sided pleural effusion
# ###################
# The report shows a small right-sided pleural effusion
# Rating the pairs:
# The report shows a small right-sided pleural effusion
# ###################
# The report shows a small left-sided pleural effusion
# Rating the pairs:
# The report shows a small right-sided pleural effusion
# ###################
# The report shows a large upper-left pleural effusion
# Rating the pairs:
# The report shows a small right-sided pleural effusion
# ###################
# The report shows a large lower-left pleural effusion
# Rating the pairs:
# The report shows a small right-sided pleural effusion
# ###################
# The report shows a large right-sided pleural effusion
# Rating the pairs:
# The report shows a small right-sided pleural effusion
# ###################
# The report shows a large left-sided pleural effusion
# Rating the pairs:
# The report shows a small right-sided pleural effusion
# ###################
# The report shows no pleural effusion
# Rating the pairs:
# The report shows a small right-sided pleural effusion
# ###################
# The report shows no consolidation on any side
# Rating the pairs:
# The report shows a small right-sided pleural effusion
# ###################
# There are no abnormalities in the report
# Rating the pairs:
# The report shows a small right-sided pleural effusion
# ###################
# There is severe consolidation in the left side
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 6
#       4 s2 = all_sentence_list[j]
#       5 print(f'Rating the pairs:\n{s1}\n###################\n{s2}')
# ----> 6 similarity_map2[f'{i}_{j}'] = rate_qa_pair(s1, s2)
#       7 time.sleep(10)
#
# Cell In[3], line 6, in rate_qa_pair(question, answer)
#       4 def rate_qa_pair(question, answer):
#       5     prompt_text = f'Rate the following pair for similarity:\n\nQuestion: {question}\nAnswer: {answer}\n\nRating out of 100:'
# ----> 6     response = openai.ChatCompletion.create(
#       7       model="gpt-4",
#       8       messages = [
#       9           {
#      10       "role": "system",
#      11       "content": content,
#      12     },
#      13     {
#      14       "role": "user",
#      15       "content": prompt_text
#      16       }
#      17       ],
#      18       temperature=0,
#      19       max_tokens=1024
#      20     )
#      21     rating = response.choices[0]['message']['content'].strip()
#      22     return rating
#
# File ~/miniconda3/envs/TutorialCuda/lib/python3.11/site-packages/openai/api_resources/chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File ~/miniconda3/envs/TutorialCuda/lib/python3.11/site-packages/openai/api_resources/abstract/engine_api_resource.py:155, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     129 @classmethod
#     130 def create(
#     131     cls,
#    (...)
#     138     **params,
#     139 ):
#     140     (
#     141         deployment_id,
#     142         engine,
#    (...)
#     152         api_key, api_base, api_type, api_version, organization, **params
#     153     )
# --> 155     response, _, api_key = requestor.request(
#     156         "post",
#     157         url,
#     158         params=params,
#     159         headers=headers,
#     160         stream=stream,
#     161         request_id=request_id,
#     162         request_timeout=request_timeout,
#     163     )
#     165     if stream:
#     166         # must be an iterator
#     167         assert not isinstance(response, OpenAIResponse)
#
# File ~/miniconda3/envs/TutorialCuda/lib/python3.11/site-packages/openai/api_requestor.py:289, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     278 def request(
#     279     self,
#     280     method,
#    (...)
#     287     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     288 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
# --> 289     result = self.request_raw(
#     290         method.lower(),
#     291         url,
#     292         params=params,
#     293         supplied_headers=headers,
#     294         files=files,
#     295         stream=stream,
#     296         request_id=request_id,
#     297         request_timeout=request_timeout,
#     298     )
#     299     resp, got_stream = self._interpret_response(result, stream)
#     300     return resp, got_stream, self.api_key
#
# File ~/miniconda3/envs/TutorialCuda/lib/python3.11/site-packages/openai/api_requestor.py:606, in APIRequestor.request_raw(self, method, url, params, supplied_headers, files, stream, request_id, request_timeout)
#     604     _thread_context.session_create_time = time.time()
#     605 try:
# --> 606     result = _thread_context.session.request(
#     607         method,
#     608         abs_url,
#     609         headers=headers,
#     610         data=data,
#     611         files=files,
#     612         stream=stream,
#     613         timeout=request_timeout if request_timeout else TIMEOUT_SECS,
#     614         proxies=_thread_context.session.proxies,
#     615     )
#     616 except requests.exceptions.Timeout as e:
#     617     raise error.Timeout("Request timed out: {}".format(e)) from e
#
# File ~/miniconda3/envs/TutorialCuda/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniconda3/envs/TutorialCuda/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/miniconda3/envs/TutorialCuda/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/miniconda3/envs/TutorialCuda/lib/python3.11/site-packages/urllib3/connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File ~/miniconda3/envs/TutorialCuda/lib/python3.11/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461             httplib_response = conn.getresponse()
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/miniconda3/envs/TutorialCuda/lib/python3.11/site-packages/urllib3/connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     458 except TypeError:
#     459     # Python 3
#     460     try:
# --> 461         httplib_response = conn.getresponse()
#     462     except BaseException as e:
#     463         # Remove the TypeError from the exception chain in
#     464         # Python 3 (including for exceptions like SystemExit).
#     465         # Otherwise it looks like a bug in the code.
#     466         six.raise_from(e, None)
#
# File ~/miniconda3/envs/TutorialCuda/lib/python3.11/http/client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File ~/miniconda3/envs/TutorialCuda/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/miniconda3/envs/TutorialCuda/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/miniconda3/envs/TutorialCuda/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~/miniconda3/envs/TutorialCuda/lib/python3.11/ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniconda3/envs/TutorialCuda/lib/python3.11/ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
for i in range(len(all_sentence_list)):
    print(','.join([similarity_map2[f'{min(i, j)}_{max(i, j)}'] for j in range(len(all_sentence_list))]))
# Out:
# 100,90,80,90,90,60,30,80,100,60,80,90,70,30,30,60,0,10,0,20,10,20,30
# 90,100,80,95,60,90,30,80,60,100,60,95,30,70,30,60,0,10,0,20,10,10,20
# 80,80,100,90,30,30,90,30,60,60,100,60,30,30,70,30,20,10,0,10,20,30,10
# 90,95,90,100,80,80,50,90,95,95,60,100,70,70,30,70,20,10,0,30,10,20,30
# 90,60,30,80,100,90,80,95,70,30,30,60,100,70,80,90,0,10,0,30,10,10,20
# 60,90,30,80,90,100,80,95,30,70,30,60,60,100,60,95,0,10,0,20,10,10,20
# 30,30,90,50,80,80,100,90,30,30,70,30,60,60,100,70,0,10,0,10,30,20,20
# 80,80,30,90,95,95,90,100,70,70,30,70,95,95,60,100,0,10,0,30,10,10,20
# 100,60,60,95,70,30,30,70,100,90,90,95,90,70,30,70,10,10,0,20,10,20,20
# 60,100,60,95,30,70,30,70,90,100,90,95,70,90,40,70,10,10,0,20,10,10,30
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 2
#       1 for i in range(len(all_sentence_list)):
# ----> 2     print(','.join([similarity_map2[f'{min(i, j)}_{max(i, j)}'] for j in range(len(all_sentence_list))]))
#
# Cell In[17], line 2, in <listcomp>(.0)
#       1 for i in range(len(all_sentence_list)):
# ----> 2     print(','.join([similarity_map2[f'{min(i, j)}_{max(i, j)}'] for j in range(len(all_sentence_list))]))
#
# KeyError: '10_19'

# %%
report_list = [dataset1_template, dataset1_pleural_issue, dataset2_template, dataset3_template]
similarity_map3 = dict()

# %%
for i in range(len(report_list)):
    for j in range(i, len(report_list)):
        s1 = report_list[i]
        s2 = report_list[j]
        print(f'Rating the pairs:\n{s1}\n###################\n{s2}')
        similarity_map3[f'{i}_{j}'] = rate_qa_pair(s1, s2)
        time.sleep(10)
# Out:
# Rating the pairs:
# xr- chest pa  view
# findings
# lungs: normal.
# trachea: normal.
# carina: normal.
# right and left main bronchi: normal.
# pleura: normal.
# heart: normal.
# right heart border: normal.
# left heart border: normal.
# pulmonary bay: normal.
# pulmonary hila: normal.
# aorta: normal.
# thoracic spine: normal.
# other visualized bones: normal.
# visualized soft tissues: normal.
# diaphragm: normal.
# visualized abdomen:  normal.
# visualized neck: normal.
# ###################
# xr- chest pa  view
# findings
# lungs: normal.
# trachea: normal.
# carina: normal.
# right and left main bronchi: normal.
# pleura: normal.
# heart: normal.
# right heart border: normal.
# left heart border: normal.
# pulmonary bay: normal.
# pulmonary hila: normal.
# aorta: normal.
# thoracic spine: normal.
# other visualized bones: normal.
# visualized soft tissues: normal.
# diaphragm: normal.
# visualized abdomen:  normal.
# visualized neck: normal.
# Rating the pairs:
# xr- chest pa  view
# findings
# lungs: normal.
# trachea: normal.
# carina: normal.
# right and left main bronchi: normal.
# pleura: normal.
# heart: normal.
# right heart border: normal.
# left heart border: normal.
# pulmonary bay: normal.
# pulmonary hila: normal.
# aorta: normal.
# thoracic spine: normal.
# other visualized bones: normal.
# visualized soft tissues: normal.
# diaphragm: normal.
# visualized abdomen:  normal.
# visualized neck: normal.
# ###################
#
# xr- chest pa view
# findings
# lungs: normal.
# trachea: normal.
# carina: normal.
# right and left main bronchi: normal.
# pleura: left costophrenic angle is blunted with thin stripe of homogenous opacity along left lateral chest wall.
# heart: normal.
# right heart border: normal.
# left heart border: normal.
# pulmonary bay: normal.
# pulmonary hila: normal.
# aorta: normal.
# thoracic spine: normal.
# other visualized bones: normal.
# visualized soft tissues: normal.
# diaphragm: normal.
# visualized abdomen:  normal.
# visualized neck: normal.
# Rating the pairs:
# xr- chest pa  view
# findings
# lungs: normal.
# trachea: normal.
# carina: normal.
# right and left main bronchi: normal.
# pleura: normal.
# heart: normal.
# right heart border: normal.
# left heart border: normal.
# pulmonary bay: normal.
# pulmonary hila: normal.
# aorta: normal.
# thoracic spine: normal.
# other visualized bones: normal.
# visualized soft tissues: normal.
# diaphragm: normal.
# visualized abdomen:  normal.
# visualized neck: normal.
# ###################
# 6191206|3862169|x-ray chest pa/ap view of 09-feb-2018:
# results:
# post cabg status.
# no focal lesion seen in the lung parenchyma.
# cp angles and domes of the diaphragm are normal.
# both hila are normal. pulmonary vasculature is normal.
# cardiac size and configuration is normal.
# trachea is central; no mediastinal shift is seen.
# bony thorax and soft tissues of the chest wall are normal.
# impression: no abnormality detected in the view obtained.
#
# Rating the pairs:
# xr- chest pa  view
# findings
# lungs: normal.
# trachea: normal.
# carina: normal.
# right and left main bronchi: normal.
# pleura: normal.
# heart: normal.
# right heart border: normal.
# left heart border: normal.
# pulmonary bay: normal.
# pulmonary hila: normal.
# aorta: normal.
# thoracic spine: normal.
# other visualized bones: normal.
# visualized soft tissues: normal.
# diaphragm: normal.
# visualized abdomen:  normal.
# visualized neck: normal.
# ###################
#
# x-ray chest (pa view)
# the cardio thoracic ratio is normal.
# the heart size and configuration are within normal limits.
# the aortic arch is normal.
# the lung fields show normal broncho-vascular markings.
# both the pulmonary hila are normal in size.
# the costophrenic and cardiophrenic recesses and the domes of
# diaphragm are normal.
# the bones and soft tissues of the chest wall show no abnormality.
# impression : normal study.
# dr.shakthi kumar
# radiologist
# ss
# ________________________________________________________
#
# Rating the pairs:
#
# xr- chest pa view
# findings
# lungs: normal.
# trachea: normal.
# carina: normal.
# right and left main bronchi: normal.
# pleura: left costophrenic angle is blunted with thin stripe of homogenous opacity along left lateral chest wall.
# heart: normal.
# right heart border: normal.
# left heart border: normal.
# pulmonary bay: normal.
# pulmonary hila: normal.
# aorta: normal.
# thoracic spine: normal.
# other visualized bones: normal.
# visualized soft tissues: normal.
# diaphragm: normal.
# visualized abdomen:  normal.
# visualized neck: normal.
# ###################
#
# xr- chest pa view
# findings
# lungs: normal.
# trachea: normal.
# carina: normal.
# right and left main bronchi: normal.
# pleura: left costophrenic angle is blunted with thin stripe of homogenous opacity along left lateral chest wall.
# heart: normal.
# right heart border: normal.
# left heart border: normal.
# pulmonary bay: normal.
# pulmonary hila: normal.
# aorta: normal.
# thoracic spine: normal.
# other visualized bones: normal.
# visualized soft tissues: normal.
# diaphragm: normal.
# visualized abdomen:  normal.
# visualized neck: normal.
# Rating the pairs:
#
# xr- chest pa view
# findings
# lungs: normal.
# trachea: normal.
# carina: normal.
# right and left main bronchi: normal.
# pleura: left costophrenic angle is blunted with thin stripe of homogenous opacity along left lateral chest wall.
# heart: normal.
# right heart border: normal.
# left heart border: normal.
# pulmonary bay: normal.
# pulmonary hila: normal.
# aorta: normal.
# thoracic spine: normal.
# other visualized bones: normal.
# visualized soft tissues: normal.
# diaphragm: normal.
# visualized abdomen:  normal.
# visualized neck: normal.
# ###################
# 6191206|3862169|x-ray chest pa/ap view of 09-feb-2018:
# results:
# post cabg status.
# no focal lesion seen in the lung parenchyma.
# cp angles and domes of the diaphragm are normal.
# both hila are normal. pulmonary vasculature is normal.
# cardiac size and configuration is normal.
# trachea is central; no mediastinal shift is seen.
# bony thorax and soft tissues of the chest wall are normal.
# impression: no abnormality detected in the view obtained.
#
# Rating the pairs:
#
# xr- chest pa view
# findings
# lungs: normal.
# trachea: normal.
# carina: normal.
# right and left main bronchi: normal.
# pleura: left costophrenic angle is blunted with thin stripe of homogenous opacity along left lateral chest wall.
# heart: normal.
# right heart border: normal.
# left heart border: normal.
# pulmonary bay: normal.
# pulmonary hila: normal.
# aorta: normal.
# thoracic spine: normal.
# other visualized bones: normal.
# visualized soft tissues: normal.
# diaphragm: normal.
# visualized abdomen:  normal.
# visualized neck: normal.
# ###################
#
# x-ray chest (pa view)
# the cardio thoracic ratio is normal.
# the heart size and configuration are within normal limits.
# the aortic arch is normal.
# the lung fields show normal broncho-vascular markings.
# both the pulmonary hila are normal in size.
# the costophrenic and cardiophrenic recesses and the domes of
# diaphragm are normal.
# the bones and soft tissues of the chest wall show no abnormality.
# impression : normal study.
# dr.shakthi kumar
# radiologist
# ss
# ________________________________________________________
#
# Rating the pairs:
# 6191206|3862169|x-ray chest pa/ap view of 09-feb-2018:
# results:
# post cabg status.
# no focal lesion seen in the lung parenchyma.
# cp angles and domes of the diaphragm are normal.
# both hila are normal. pulmonary vasculature is normal.
# cardiac size and configuration is normal.
# trachea is central; no mediastinal shift is seen.
# bony thorax and soft tissues of the chest wall are normal.
# impression: no abnormality detected in the view obtained.
#
# ###################
# 6191206|3862169|x-ray chest pa/ap view of 09-feb-2018:
# results:
# post cabg status.
# no focal lesion seen in the lung parenchyma.
# cp angles and domes of the diaphragm are normal.
# both hila are normal. pulmonary vasculature is normal.
# cardiac size and configuration is normal.
# trachea is central; no mediastinal shift is seen.
# bony thorax and soft tissues of the chest wall are normal.
# impression: no abnormality detected in the view obtained.
#
# Rating the pairs:
# 6191206|3862169|x-ray chest pa/ap view of 09-feb-2018:
# results:
# post cabg status.
# no focal lesion seen in the lung parenchyma.
# cp angles and domes of the diaphragm are normal.
# both hila are normal. pulmonary vasculature is normal.
# cardiac size and configuration is normal.
# trachea is central; no mediastinal shift is seen.
# bony thorax and soft tissues of the chest wall are normal.
# impression: no abnormality detected in the view obtained.
#
# ###################
#
# x-ray chest (pa view)
# the cardio thoracic ratio is normal.
# the heart size and configuration are within normal limits.
# the aortic arch is normal.
# the lung fields show normal broncho-vascular markings.
# both the pulmonary hila are normal in size.
# the costophrenic and cardiophrenic recesses and the domes of
# diaphragm are normal.
# the bones and soft tissues of the chest wall show no abnormality.
# impression : normal study.
# dr.shakthi kumar
# radiologist
# ss
# ________________________________________________________
#
# Rating the pairs:
#
# x-ray chest (pa view)
# the cardio thoracic ratio is normal.
# the heart size and configuration are within normal limits.
# the aortic arch is normal.
# the lung fields show normal broncho-vascular markings.
# both the pulmonary hila are normal in size.
# the costophrenic and cardiophrenic recesses and the domes of
# diaphragm are normal.
# the bones and soft tissues of the chest wall show no abnormality.
# impression : normal study.
# dr.shakthi kumar
# radiologist
# ss
# ________________________________________________________
#
# ###################
#
# x-ray chest (pa view)
# the cardio thoracic ratio is normal.
# the heart size and configuration are within normal limits.
# the aortic arch is normal.
# the lung fields show normal broncho-vascular markings.
# both the pulmonary hila are normal in size.
# the costophrenic and cardiophrenic recesses and the domes of
# diaphragm are normal.
# the bones and soft tissues of the chest wall show no abnormality.
# impression : normal study.
# dr.shakthi kumar
# radiologist
# ss
# ________________________________________________________

# %%
for i in range(len(report_list)):
    print(','.join([similarity_map3[f'{min(i, j)}_{max(i, j)}'] for j in range(len(report_list))]))
# Out:
# 100,90,95,95
# 90,100,80,85
# 95,80,100,95
# 95,85,95,100
